# %%
# !pip install -qq tensorflow
# !pip install transformers==4.42.1 -U
# !pip install sentencepiece
# !pip install torch==2.2.2
# !pip install torchtext==0.17.2
# !pip install numpy==1.26
#!pip install --upgrade numpy transformers torch
# Out:
# Collecting transformers==4.42.1
#   Obtaining dependency information for transformers==4.42.1 from https://files.pythonhosted.org/packages/32/a5/ad96309b47ede58104e109689819e24749c7b5bb1d935257240dbefe28dd/transformers-4.42.1-py3-none-any.whl.metadata
#   Downloading transformers-4.42.1-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 1.0 MB/s eta 0:00:00a 0:00:01
# Collecting filelock (from transformers==4.42.1)
#   Obtaining dependency information for filelock from https://files.pythonhosted.org/packages/4d/36/2a115987e2d8c300a974597416d9de88f2444426de9571f4b59b2cca3acc/filelock-3.18.0-py3-none-any.whl.metadata
#   Downloading filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting huggingface-hub<1.0,>=0.23.2 (from transformers==4.42.1)
#   Obtaining dependency information for huggingface-hub<1.0,>=0.23.2 from https://files.pythonhosted.org/packages/59/a8/4677014e771ed1591a87b63a2392ce6923baf807193deef302dcfde17542/huggingface_hub-0.34.3-py3-none-any.whl.metadata
#   Downloading huggingface_hub-0.34.3-py3-none-any.whl.metadata (14 kB)
# Collecting numpy<2.0,>=1.17 (from transformers==4.42.1)
#   Obtaining dependency information for numpy<2.0,>=1.17 from https://files.pythonhosted.org/packages/ae/8c/ab03a7c25741f9ebc92684a20125fbc9fc1b8e1e700beb9197d750fdff88/numpy-1.26.4-cp39-cp39-macosx_11_0_arm64.whl.metadata
#   Downloading numpy-1.26.4-cp39-cp39-macosx_11_0_arm64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /Users/mbisht/Learning/LLM/github/llm/.venv/lib/python3.9/site-packages (from transformers==4.42.1) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/mbisht/Learning/LLM/github/llm/.venv/lib/python3.9/site-packages (from transformers==4.42.1) (6.0.2)
# Collecting regex!=2019.12.17 (from transformers==4.42.1)
#   Obtaining dependency information for regex!=2019.12.17 from https://files.pythonhosted.org/packages/46/cc/5c9ebdc23b34458a41b559e0ae1b759196b2212920164b9d8aae4b25aa26/regex-2025.7.34-cp39-cp39-macosx_11_0_arm64.whl.metadata
#   Downloading regex-2025.7.34-cp39-cp39-macosx_11_0_arm64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: requests in /Users/mbisht/Learning/LLM/github/llm/.venv/lib/python3.9/site-packages (from transformers==4.42.1) (2.32.4)
# Collecting tokenizers<0.20,>=0.19 (from transformers==4.42.1)
#   Obtaining dependency information for tokenizers<0.20,>=0.19 from https://files.pythonhosted.org/packages/0a/2b/4e5718e806ff23e5e758e02bd4b34967b5218f085b0c189335fd27c14dc1/tokenizers-0.19.1-cp39-cp39-macosx_11_0_arm64.whl.metadata
#   Downloading tokenizers-0.19.1-cp39-cp39-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Collecting safetensors>=0.4.1 (from transformers==4.42.1)
#   Obtaining dependency information for safetensors>=0.4.1 from https://files.pythonhosted.org/packages/b8/3b/11f1b4a2f5d2ab7da34ecc062b0bc301f2be024d110a6466726bec8c055c/safetensors-0.5.3-cp38-abi3-macosx_11_0_arm64.whl.metadata
#   Downloading safetensors-0.5.3-cp38-abi3-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Collecting tqdm>=4.27 (from transformers==4.42.1)
#   Obtaining dependency information for tqdm>=4.27 from https://files.pythonhosted.org/packages/d0/30/dc54f88dd4a2b5dc8a0279bdd7270e735851848b762aeb1c1184ed1f6b14/tqdm-4.67.1-py3-none-any.whl.metadata
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 5.7 MB/s eta 0:00:00
# Collecting fsspec>=2023.5.0 (from huggingface-hub<1.0,>=0.23.2->transformers==4.42.1)
#   Obtaining dependency information for fsspec>=2023.5.0 from https://files.pythonhosted.org/packages/2f/e0/014d5d9d7a4564cf1c40b5039bc882db69fd881111e03ab3657ac0b218e2/fsspec-2025.7.0-py3-none-any.whl.metadata
#   Downloading fsspec-2025.7.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/mbisht/Learning/LLM/github/llm/.venv/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.42.1) (4.14.1)
# Collecting hf-xet<2.0.0,>=1.1.3 (from huggingface-hub<1.0,>=0.23.2->transformers==4.42.1)
#   Obtaining dependency information for hf-xet<2.0.0,>=1.1.3 from https://files.pythonhosted.org/packages/de/5f/2c78e28f309396e71ec8e4e9304a6483dcbc36172b5cea8f291994163425/hf_xet-1.1.5-cp37-abi3-macosx_11_0_arm64.whl.metadata
#   Downloading hf_xet-1.1.5-cp37-abi3-macosx_11_0_arm64.whl.metadata (879 bytes)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/mbisht/Learning/LLM/github/llm/.venv/lib/python3.9/site-packages (from requests->transformers==4.42.1) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mbisht/Learning/LLM/github/llm/.venv/lib/python3.9/site-packages (from requests->transformers==4.42.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mbisht/Learning/LLM/github/llm/.venv/lib/python3.9/site-packages (from requests->transformers==4.42.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mbisht/Learning/LLM/github/llm/.venv/lib/python3.9/site-packages (from requests->transformers==4.42.1) (2025.7.14)
# Downloading transformers-4.42.1-py3-none-any.whl (9.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 26.8 MB/s eta 0:00:0000:0100:01
# Downloading huggingface_hub-0.34.3-py3-none-any.whl (558 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 558.8/558.8 kB 24.2 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp39-cp39-macosx_11_0_arm64.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 26.0 MB/s eta 0:00:0000:0100:01
# Downloading regex-2025.7.34-cp39-cp39-macosx_11_0_arm64.whl (285 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.9/285.9 kB 23.7 MB/s eta 0:00:00
# Downloading safetensors-0.5.3-cp38-abi3-macosx_11_0_arm64.whl (418 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 418.4/418.4 kB 17.3 MB/s eta 0:00:00
# Downloading tokenizers-0.19.1-cp39-cp39-macosx_11_0_arm64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 24.1 MB/s eta 0:00:00a 0:00:01
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 8.2 MB/s eta 0:00:00
# Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading fsspec-2025.7.0-py3-none-any.whl (199 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.6/199.6 kB 21.1 MB/s eta 0:00:00
# Downloading hf_xet-1.1.5-cp37-abi3-macosx_11_0_arm64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 25.0 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: tqdm, safetensors, regex, numpy, hf-xet, fsspec, filelock, huggingface-hub, tokenizers, transformers
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# Successfully installed filelock-3.18.0 fsspec-2025.7.0 hf-xet-1.1.5 huggingface-hub-0.34.3 numpy-1.26.4 regex-2025.7.34 safetensors-0.5.3 tokenizers-0.19.1 tqdm-4.67.1 transformers-4.42.1
#
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Collecting sentencepiece
#   Obtaining dependency information for sentencepiece from https://files.pythonhosted.org/packages/79/91/b54a528e0789cd7986341ed3909bec56365c3b672daef8b10aa4098238f0/sentencepiece-0.2.0-cp39-cp39-macosx_11_0_arm64.whl.metadata
#   Downloading sentencepiece-0.2.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (7.7 kB)
# Downloading sentencepiece-0.2.0-cp39-cp39-macosx_11_0_arm64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 3.7 MB/s eta 0:00:0000:0100:01
# Installing collected packages: sentencepiece
# Successfully installed sentencepiece-0.2.0
#
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Collecting torch==2.2.2
#   Obtaining dependency information for torch==2.2.2 from https://files.pythonhosted.org/packages/e9/22/b9666424fd3745b1dc5d83ed08baffa6bbf7dddd425067420c4100319402/torch-2.2.2-cp39-none-macosx_11_0_arm64.whl.metadata
#   Downloading torch-2.2.2-cp39-none-macosx_11_0_arm64.whl.metadata (25 kB)
# Requirement already satisfied: filelock in /Users/mbisht/Learning/LLM/github/llm/.venv/lib/python3.9/site-packages (from torch==2.2.2) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/mbisht/Learning/LLM/github/llm/.venv/lib/python3.9/site-packages (from torch==2.2.2) (4.14.1)
# Collecting sympy (from torch==2.2.2)
#   Obtaining dependency information for sympy from https://files.pythonhosted.org/packages/a2/09/77d55d46fd61b4a135c444fc97158ef34a095e5681d0a6c10b75bf356191/sympy-1.14.0-py3-none-any.whl.metadata
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch==2.2.2)
#   Obtaining dependency information for networkx from https://files.pythonhosted.org/packages/d5/f0/8fbc882ca80cf077f1b246c0e3c3465f7f415439bdea6b899f6b19f61f70/networkx-3.2.1-py3-none-any.whl.metadata
#   Downloading networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: jinja2 in /Users/mbisht/Learning/LLM/github/llm/.venv/lib/python3.9/site-packages (from torch==2.2.2) (3.1.6)
# Requirement already satisfied: fsspec in /Users/mbisht/Learning/LLM/github/llm/.venv/lib/python3.9/site-packages (from torch==2.2.2) (2025.7.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/mbisht/Learning/LLM/github/llm/.venv/lib/python3.9/site-packages (from jinja2->torch==2.2.2) (3.0.2)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->torch==2.2.2)
#   Obtaining dependency information for mpmath<1.4,>=1.1.0 from https://files.pythonhosted.org/packages/43/e3/7d92a15f894aa0c9c4b49b8ee9ac9850d6e63b03c9c32c0367a13ae62209/mpmath-1.3.0-py3-none-any.whl.metadata
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading torch-2.2.2-cp39-none-macosx_11_0_arm64.whl (59.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.7/59.7 MB 9.9 MB/s eta 0:00:00:00:0100:01
# Downloading networkx-3.2.1-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 5.1 MB/s eta 0:00:00a 0:00:01m
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 4.4 MB/s eta 0:00:0000:0100:01m
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 2.0 MB/s eta 0:00:0000:01:00:01
# Installing collected packages: mpmath, sympy, networkx, torch
# Successfully installed mpmath-1.3.0 networkx-3.2.1 sympy-1.14.0 torch-2.2.2
#
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Collecting torchtext==0.17.2
#   Obtaining dependency information for torchtext==0.17.2 from https://files.pythonhosted.org/packages/64/4b/e1ca9501631565c47e3a52eb8b3849a26f5364ffb3651f853d1a9524ca23/torchtext-0.17.2-cp39-cp39-macosx_11_0_arm64.whl.metadata
#   Downloading torchtext-0.17.2-cp39-cp39-macosx_11_0_arm64.whl.metadata (7.9 kB)
# Requirement already satisfied: tqdm in /Users/mbisht/Learning/LLM/github/llm/.venv/lib/python3.9/site-packages (from torchtext==0.17.2) (4.67.1)
# Requirement already satisfied: requests in /Users/mbisht/Learning/LLM/github/llm/.venv/lib/python3.9/site-packages (from torchtext==0.17.2) (2.32.4)
# Requirement already satisfied: torch==2.2.2 in /Users/mbisht/Learning/LLM/github/llm/.venv/lib/python3.9/site-packages (from torchtext==0.17.2) (2.2.2)
# Requirement already satisfied: numpy in /Users/mbisht/Learning/LLM/github/llm/.venv/lib/python3.9/site-packages (from torchtext==0.17.2) (1.26.4)
# Requirement already satisfied: filelock in /Users/mbisht/Learning/LLM/github/llm/.venv/lib/python3.9/site-packages (from torch==2.2.2->torchtext==0.17.2) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/mbisht/Learning/LLM/github/llm/.venv/lib/python3.9/site-packages (from torch==2.2.2->torchtext==0.17.2) (4.14.1)
# Requirement already satisfied: sympy in /Users/mbisht/Learning/LLM/github/llm/.venv/lib/python3.9/site-packages (from torch==2.2.2->torchtext==0.17.2) (1.14.0)
# Requirement already satisfied: networkx in /Users/mbisht/Learning/LLM/github/llm/.venv/lib/python3.9/site-packages (from torch==2.2.2->torchtext==0.17.2) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/mbisht/Learning/LLM/github/llm/.venv/lib/python3.9/site-packages (from torch==2.2.2->torchtext==0.17.2) (3.1.6)
# Requirement already satisfied: fsspec in /Users/mbisht/Learning/LLM/github/llm/.venv/lib/python3.9/site-packages (from torch==2.2.2->torchtext==0.17.2) (2025.7.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/mbisht/Learning/LLM/github/llm/.venv/lib/python3.9/site-packages (from requests->torchtext==0.17.2) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mbisht/Learning/LLM/github/llm/.venv/lib/python3.9/site-packages (from requests->torchtext==0.17.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mbisht/Learning/LLM/github/llm/.venv/lib/python3.9/site-packages (from requests->torchtext==0.17.2) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mbisht/Learning/LLM/github/llm/.venv/lib/python3.9/site-packages (from requests->torchtext==0.17.2) (2025.7.14)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/mbisht/Learning/LLM/github/llm/.venv/lib/python3.9/site-packages (from jinja2->torch==2.2.2->torchtext==0.17.2) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/mbisht/Learning/LLM/github/llm/.venv/lib/python3.9/site-packages (from sympy->torch==2.2.2->torchtext==0.17.2) (1.3.0)
# Downloading torchtext-0.17.2-cp39-cp39-macosx_11_0_arm64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 5.3 MB/s eta 0:00:0000:0100:01
# Installing collected packages: torchtext
# Successfully installed torchtext-0.17.2
#
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Collecting numpy==1.26
#   Obtaining dependency information for numpy==1.26 from https://files.pythonhosted.org/packages/b4/ca/fc1c4f8a2a4693ff437d039acf2dc93a190b9494569fbed246f535c44fc8/numpy-1.26.0-cp39-cp39-macosx_11_0_arm64.whl.metadata
#   Downloading numpy-1.26.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.5/53.5 kB 1.1 MB/s eta 0:00:00a 0:00:01
# Downloading numpy-1.26.0-cp39-cp39-macosx_11_0_arm64.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 24.6 MB/s eta 0:00:0000:0100:01
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# Successfully installed numpy-1.26.0
#
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

# Selecting the model. You will be using "facebook/blenderbot-400M-distill" in this example.
model_name = "facebook/blenderbot-400M-distill"

# Load the model and tokenizer
model = AutoModelForSeq2SeqLM.from_pretrained(model_name)
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
# Define the chat function
def chat_with_bot():
    while True:
        # Get user input
        input_text = input("You: ")

        # Exit conditions
        if input_text.lower() in ["quit", "exit", "bye"]:
            print("Chatbot: Goodbye!")
            break

        # Tokenize input and generate response
        inputs = tokenizer.encode(input_text, return_tensors="pt")
        outputs = model.generate(inputs, max_new_tokens=150)
        response = tokenizer.decode(outputs[0], skip_special_tokens=True).strip()

        # Display bot's response
        print("Chatbot:", response)

# Start chatting
chat_with_bot()
# Out:
# Chatbot: I'm not sure, but I do know that the US has the highest population density of any country in the world.
# Chatbot: I'm not sure, but I do know that it's the 3rd most populous state in the US.
# Chatbot: I would love to go to New Orleans. It is the most populous city in the United States.
# Chatbot: I would recommend going to Hawaii. It is the most beautiful place in the world.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 21
#      18         print("Chatbot:", response)
#      20 # Start chatting
# ---> 21 chat_with_bot()
#
# Cell In[4], line 5, in chat_with_bot()
#       2 def chat_with_bot():
#       3     while True:
#       4         # Get user input
# ----> 5         input_text = input("You: ")
#       7         # Exit conditions
#       8         if input_text.lower() in ["quit", "exit", "bye"]:
#
# File ~/Learning/LLM/github/llm/.venv/lib/python3.9/site-packages/ipykernel/kernelbase.py:1260, in Kernel.raw_input(self, prompt)
#    1258     msg = "raw_input was called, but this frontend does not support input requests."
#    1259     raise StdinNotImplementedError(msg)
# -> 1260 return self._input_request(
#    1261     str(prompt),
#    1262     self._parent_ident["shell"],
#    1263     self.get_parent("shell"),
#    1264     password=False,
#    1265 )
#
# File ~/Learning/LLM/github/llm/.venv/lib/python3.9/site-packages/ipykernel/kernelbase.py:1305, in Kernel._input_request(self, prompt, ident, parent, password)
#    1302 except KeyboardInterrupt:
#    1303     # re-raise KeyboardInterrupt, to truncate traceback
#    1304     msg = "Interrupted by user"
# -> 1305     raise KeyboardInterrupt(msg) from None
#    1306 except Exception:
#    1307     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
